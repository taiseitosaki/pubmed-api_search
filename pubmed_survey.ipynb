# %%
import pandas as pd
from Bio import Entrez  # なければ追加install
import openpyxl  # なければ追加install
import time

# %%
df = pd.DataFrame([[
    'Respiratory V25',
    'AtopicDermatitis',
    'BodyComposition Status',
    'Body Water Mass',
    'Creatinine',
    'DailyLife Feelings Enjoyable',
    'Eating Habit Butter',
    'Exercise Habit Mountain Hiking',
    'baPWV',
    'Health Status Doctor Dementia',
    'Health Status Doctor HTN',
    'Health Status Doctor Pancreas',
    'Heart Disease',
    'Hypertension',
    'Right-Left Arm LeanMass',
    'Right-Left Leg R_50kHz impedance',
    'Weed Allergy I'
],[
    "Obesity",
    "COPD",
    "COPD & Obesity",
    "Hypertension",
    "CKD",
    "Obesity",
    "Diabetes & Obesity",
    "Hypertension & Diabetes & Obesity",
    "Arteriosclerosis",
    "COPD & Obesity",
    "Hypertension",
    "Diabetes",
    "Diabetes",
    "Hypertension",
    "Hypertension",
    "Obesity",
    "COPD & Obesity"
]], index = ["check_item", "disease"]).T
df
# Out:
#                           check_item                            disease
# 0                    Respiratory V25                            Obesity
# 1                   AtopicDermatitis                               COPD
# 2             BodyComposition Status                     COPD & Obesity
# 3                    Body Water Mass                       Hypertension
# 4                         Creatinine                                CKD
# 5       DailyLife Feelings Enjoyable                            Obesity
# 6                Eating Habit Butter                 Diabetes & Obesity
# 7     Exercise Habit Mountain Hiking  Hypertension & Diabetes & Obesity
# 8                              baPWV                   Arteriosclerosis
# 9      Health Status Doctor Dementia                     COPD & Obesity
# 10          Health Status Doctor HTN                       Hypertension
# 11     Health Status Doctor Pancreas                           Diabetes
# 12                     Heart Disease                           Diabetes
# 13                      Hypertension                       Hypertension
# 14           Right-Left Arm LeanMass                       Hypertension
# 15  Right-Left Leg R_50kHz impedance                            Obesity
# 16                    Weed Allergy I                     COPD & Obesity

# %% [markdown]
# 上記の1対1ペアを検索するのが以下。emailの部分は変更必要（というか最初にアカウント登録しないといけない。）です。

# %%
import time
import pandas as pd
from Bio import Entrez

# ── 設定 ──
Entrez.email = "YOUR_MAIL_ADDRESS"
#Entrez.api_key = "YOUR_NCBI_API_KEY"
MAX_PER_QUERY = 5
DELAY = 0.34
YEAR_RANGE = ("2015", "2024")
RELATIONS = ["association", "risk", "correlation"]

RELATIONS = ["association", "stratification"]
MAX_PER_QUERY = 5
DELAY = 0.34

def make_query(item: str, disease: str, relation: str) -> str:
    group = lambda term: f'("{term}"[TIAB] OR "{term}"[MeSH])'
    return (
        f"{group(item)} AND {group(disease)} AND {relation}[TIAB] "
        f'AND ("2015"[PDAT] : "2024"[PDAT]) AND Humans[Mesh]'
    )

def search_and_fetch(query: str) -> list[dict]:
    handle = Entrez.esearch(db="pubmed", term=query, retmax=MAX_PER_QUERY)
    ids = Entrez.read(handle)["IdList"]
    handle.close()
    if not ids:
        return []
    records = Entrez.read(
        Entrez.efetch(db="pubmed", id=",".join(ids), rettype="medline", retmode="xml")
    )["PubmedArticle"]

    results = []
    for rec in records:
        pmid = rec["MedlineCitation"]["PMID"]
        art = rec["MedlineCitation"]["Article"]
        results.append({
            "PMID": pmid,
            "Link": f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/",
            "Title": art.get("ArticleTitle", ""),
            "Journal": art.get("Journal", {}).get("Title", ""),
            "PubDate": art.get("Journal", {}).get("JournalIssue", {}).get("PubDate", {}).get("Year", ""),
            "Abstract": " ".join(art.get("Abstract", {}).get("AbstractText", []))
        })
    return results

def batch_pubmed_search(df: pd.DataFrame) -> pd.DataFrame:
    rows = []
    for _, r in df.iterrows():
        for rel in RELATIONS:
            q = make_query(r.check_item, r.disease, rel)
            for paper in search_and_fetch(q):
                rows.append({
                    "check_item": r.check_item,
                    "disease": r.disease,
                    "relation": rel,
                    "query": q,
                    **paper
                })
            time.sleep(DELAY)
    return pd.DataFrame(rows)

# %%
df_results = batch_pubmed_search(df)
df_results
# Out:
#          check_item           disease        relation  \
# 0   Body Water Mass      Hypertension     association
# 1        Creatinine               CKD     association
# 2        Creatinine               CKD     association
# 3        Creatinine               CKD     association
# 4        Creatinine               CKD     association
# 5        Creatinine               CKD     association
# 6        Creatinine               CKD  stratification
# 7        Creatinine               CKD  stratification
# 8        Creatinine               CKD  stratification
# 9        Creatinine               CKD  stratification
# 10       Creatinine               CKD  stratification
# 11            baPWV  Arteriosclerosis     association
# 12            baPWV  Arteriosclerosis     association
# 13            baPWV  Arteriosclerosis     association
# 14            baPWV  Arteriosclerosis     association
# 15            baPWV  Arteriosclerosis     association
# 16            baPWV  Arteriosclerosis  stratification
# 17            baPWV  Arteriosclerosis  stratification
# 18            baPWV  Arteriosclerosis  stratification
# 19            baPWV  Arteriosclerosis  stratification
# 20            baPWV  Arteriosclerosis  stratification
# 21    Heart Disease          Diabetes     association
# 22    Heart Disease          Diabetes     association
# 23    Heart Disease          Diabetes     association
# 24    Heart Disease          Diabetes     association
# 25    Heart Disease          Diabetes     association
# 26    Heart Disease          Diabetes  stratification
# 27    Heart Disease          Diabetes  stratification
# 28    Heart Disease          Diabetes  stratification
# 29    Heart Disease          Diabetes  stratification
# 30    Heart Disease          Diabetes  stratification
# 31     Hypertension      Hypertension     association
# 32     Hypertension      Hypertension     association
# 33     Hypertension      Hypertension     association
# 34     Hypertension      Hypertension     association
# 35     Hypertension      Hypertension     association
# 36     Hypertension      Hypertension  stratification
# 37     Hypertension      Hypertension  stratification
# 38     Hypertension      Hypertension  stratification
# 39     Hypertension      Hypertension  stratification
# 40     Hypertension      Hypertension  stratification
#
#                                                 query      PMID  \
# 0   ("Body Water Mass"[TIAB] OR "Body Water Mass"[...  38085646
# 1   ("Creatinine"[TIAB] OR "Creatinine"[MeSH]) AND...  39977186
# 2   ("Creatinine"[TIAB] OR "Creatinine"[MeSH]) AND...  39831490
# 3   ("Creatinine"[TIAB] OR "Creatinine"[MeSH]) AND...  39743167
# 4   ("Creatinine"[TIAB] OR "Creatinine"[MeSH]) AND...  39740300
# 5   ("Creatinine"[TIAB] OR "Creatinine"[MeSH]) AND...  39698033
# 6   ("Creatinine"[TIAB] OR "Creatinine"[MeSH]) AND...  39631491
# 7   ("Creatinine"[TIAB] OR "Creatinine"[MeSH]) AND...  39497801
# 8   ("Creatinine"[TIAB] OR "Creatinine"[MeSH]) AND...  39382257
# 9   ("Creatinine"[TIAB] OR "Creatinine"[MeSH]) AND...  39369692
# 10  ("Creatinine"[TIAB] OR "Creatinine"[MeSH]) AND...  38965471
# 11  ("baPWV"[TIAB] OR "baPWV"[MeSH]) AND ("Arterio...  39672744
# 12  ("baPWV"[TIAB] OR "baPWV"[MeSH]) AND ("Arterio...  39311791
# 13  ("baPWV"[TIAB] OR "baPWV"[MeSH]) AND ("Arterio...  39122757
# 14  ("baPWV"[TIAB] OR "baPWV"[MeSH]) AND ("Arterio...  38641617
# 15  ("baPWV"[TIAB] OR "baPWV"[MeSH]) AND ("Arterio...  38539102
# 16  ("baPWV"[TIAB] OR "baPWV"[MeSH]) AND ("Arterio...  38539102
# 17  ("baPWV"[TIAB] OR "baPWV"[MeSH]) AND ("Arterio...  37522647
# 18  ("baPWV"[TIAB] OR "baPWV"[MeSH]) AND ("Arterio...  36826736
# 19  ("baPWV"[TIAB] OR "baPWV"[MeSH]) AND ("Arterio...  36728780
# 20  ("baPWV"[TIAB] OR "baPWV"[MeSH]) AND ("Arterio...  36161704
# 21  ("Heart Disease"[TIAB] OR "Heart Disease"[MeSH...  39990839
# 22  ("Heart Disease"[TIAB] OR "Heart Disease"[MeSH...  39784132
# 23  ("Heart Disease"[TIAB] OR "Heart Disease"[MeSH...  39781312
# 24  ("Heart Disease"[TIAB] OR "Heart Disease"[MeSH...  39770938
# 25  ("Heart Disease"[TIAB] OR "Heart Disease"[MeSH...  39749021
# 26  ("Heart Disease"[TIAB] OR "Heart Disease"[MeSH...  39732905
# 27  ("Heart Disease"[TIAB] OR "Heart Disease"[MeSH...  39645511
# 28  ("Heart Disease"[TIAB] OR "Heart Disease"[MeSH...  39528344
# 29  ("Heart Disease"[TIAB] OR "Heart Disease"[MeSH...  39510048
# 30  ("Heart Disease"[TIAB] OR "Heart Disease"[MeSH...  39420367
# 31  ("Hypertension"[TIAB] OR "Hypertension"[MeSH])...  40074311
# 32  ("Hypertension"[TIAB] OR "Hypertension"[MeSH])...  40053020
# 33  ("Hypertension"[TIAB] OR "Hypertension"[MeSH])...  40031467
# 34  ("Hypertension"[TIAB] OR "Hypertension"[MeSH])...  39996346
# 35  ("Hypertension"[TIAB] OR "Hypertension"[MeSH])...  39986937
# 36  ("Hypertension"[TIAB] OR "Hypertension"[MeSH])...  40104301
# 37  ("Hypertension"[TIAB] OR "Hypertension"[MeSH])...  40074311
# 38  ("Hypertension"[TIAB] OR "Hypertension"[MeSH])...  40040139
# 39  ("Hypertension"[TIAB] OR "Hypertension"[MeSH])...  39863382
# 40  ("Hypertension"[TIAB] OR "Hypertension"[MeSH])...  39817915
#
#                                          Link  \
# 0   https://pubmed.ncbi.nlm.nih.gov/38085646/
# 1   https://pubmed.ncbi.nlm.nih.gov/39977186/
# 2   https://pubmed.ncbi.nlm.nih.gov/39831490/
# 3   https://pubmed.ncbi.nlm.nih.gov/39743167/
# 4   https://pubmed.ncbi.nlm.nih.gov/39740300/
# 5   https://pubmed.ncbi.nlm.nih.gov/39698033/
# 6   https://pubmed.ncbi.nlm.nih.gov/39631491/
# 7   https://pubmed.ncbi.nlm.nih.gov/39497801/
# 8   https://pubmed.ncbi.nlm.nih.gov/39382257/
# 9   https://pubmed.ncbi.nlm.nih.gov/39369692/
# 10  https://pubmed.ncbi.nlm.nih.gov/38965471/
# 11  https://pubmed.ncbi.nlm.nih.gov/39672744/
# 12  https://pubmed.ncbi.nlm.nih.gov/39311791/
# 13  https://pubmed.ncbi.nlm.nih.gov/39122757/
# 14  https://pubmed.ncbi.nlm.nih.gov/38641617/
# 15  https://pubmed.ncbi.nlm.nih.gov/38539102/
# 16  https://pubmed.ncbi.nlm.nih.gov/38539102/
# 17  https://pubmed.ncbi.nlm.nih.gov/37522647/
# 18  https://pubmed.ncbi.nlm.nih.gov/36826736/
# 19  https://pubmed.ncbi.nlm.nih.gov/36728780/
# 20  https://pubmed.ncbi.nlm.nih.gov/36161704/
# 21  https://pubmed.ncbi.nlm.nih.gov/39990839/
# 22  https://pubmed.ncbi.nlm.nih.gov/39784132/
# 23  https://pubmed.ncbi.nlm.nih.gov/39781312/
# 24  https://pubmed.ncbi.nlm.nih.gov/39770938/
# 25  https://pubmed.ncbi.nlm.nih.gov/39749021/
# 26  https://pubmed.ncbi.nlm.nih.gov/39732905/
# 27  https://pubmed.ncbi.nlm.nih.gov/39645511/
# 28  https://pubmed.ncbi.nlm.nih.gov/39528344/
# 29  https://pubmed.ncbi.nlm.nih.gov/39510048/
# 30  https://pubmed.ncbi.nlm.nih.gov/39420367/
# 31  https://pubmed.ncbi.nlm.nih.gov/40074311/
# 32  https://pubmed.ncbi.nlm.nih.gov/40053020/
# 33  https://pubmed.ncbi.nlm.nih.gov/40031467/
# 34  https://pubmed.ncbi.nlm.nih.gov/39996346/
# 35  https://pubmed.ncbi.nlm.nih.gov/39986937/
# 36  https://pubmed.ncbi.nlm.nih.gov/40104301/
# 37  https://pubmed.ncbi.nlm.nih.gov/40074311/
# 38  https://pubmed.ncbi.nlm.nih.gov/40040139/
# 39  https://pubmed.ncbi.nlm.nih.gov/39863382/
# 40  https://pubmed.ncbi.nlm.nih.gov/39817915/
#
#                                                 Title  \
# 0   Association of modifiable risk factors with ob...
# 1                                    [Not Available].
# 2   Correlation between Serum Biomarkers and Disea...
# 3   Association of Serum Afamin Concentrations Wit...
# 4   Association of creatinine-to-cystatin C ratio ...
# 5   The association of RBP4 with chronic kidney di...
# 6   Risk of Bleeding, Thrombosis and Death among A...
# 7   U-shaped association between dietary niacin in...
# 8   Albuminuria-based stratification of end-stage ...
# 9   The Impact of Primary Renal Diagnosis on Progn...
# 10  Prevalence and associated factors of impaired ...
# 11  Association between brachial-ankle pulse wave ...
# 12  Association between triglyceride<b>-</b>glucos...
# 13  Association between insulin resistance and vas...
# 14  Remnant cholesterol trajectory and subclinical...
# 15  Correlation between the cardiometabolic index ...
# 16  Correlation between the cardiometabolic index ...
# 17  The incidence of subclinical atherosclerosis i...
# 18  Association between length of daily siesta and...
# 19  One-month changes in blood pressure-adjusted p...
# 20  Sex differences in the association between vis...
# 21  [Causal Relationship Between Components of Met...
# 22  Association of Severity of Coronary Artery Dis...
# 23  Mortality predictors in acute myocardial infar...
# 24  Associations Between Knowledge of Health Condi...
# 25  Analysis of the risk of death and its associat...
# 26  Predictive value of system immune-inflammation...
# 27  Cardiovascular-kidney-metabolic syndrome defin...
# 28  [Cognitive function groups in older people and...
# 29  Recurrent Hospitalizations for Fluid Overload ...
# 30  Unseen threat: how subclinical atherosclerosis...
# 31  Cystatin C is associated with osteoporosis and...
# 32  [Idiopathic Intracranial Hypertension: Clinica...
# 33  Continuous Blood Pressure Monitoring and Hyper...
# 34  Multivariate Joint Analysis of Blood Pressure ...
# 35  Sex- and metabolic-specific association betwee...
# 36  Navigating pregnancy with cardiovascular disea...
# 37  Cystatin C is associated with osteoporosis and...
# 38  Capturing Physiological Correlates of Stress-I...
# 39  The Role of Imaging in Pulmonary Vascular Dise...
# 40  Long-term outcome and risk stratification in c...
#
#                                               Journal PubDate  \
# 0                                               Aging    2023
# 1                             Salud publica de Mexico    2024
# 2   British journal of hospital medicine (London, ...    2024
# 3   American journal of kidney diseases : the offi...    2025
# 4            Clinical nutrition (Edinburgh, Scotland)    2025
# 5                          Frontiers in endocrinology    2024
# 6                  The American journal of cardiology    2025
# 7                          Frontiers in endocrinology    2024
# 8                                     Pharmacotherapy    2024
# 9                      American journal of nephrology    2025
# 10                                     BMC pediatrics    2024
# 11  Nutrition, metabolism, and cardiovascular dise...    2025
# 12  Zhong nan da xue xue bao. Yi xue ban = Journal...    2024
# 13                                 Scientific reports    2024
# 14                                 Scientific reports    2024
# 15                       BMC cardiovascular disorders    2024
# 16                       BMC cardiovascular disorders    2024
# 17                                Clinical cardiology    2023
# 18                Sleep & breathing = Schlaf & Atmung    2023
# 19                            Journal of hypertension    2023
# 20                  Journal of diabetes investigation    2023
# 21  Sichuan da xue xue bao. Yi xue ban = Journal o...    2024
# 22                                       Kardiologiia    2024
# 23                       Journal of medicine and life    2024
# 24                                          Nutrients    2024
# 25                         Frontiers in endocrinology    2024
# 26                                 Scientific reports    2024
# 27                                         Nefrologia    2024
# 28  Revista medica del Instituto Mexicano del Segu...    2024
# 29                               Cardiorenal medicine    2024
# 30                         Cardiovascular diabetology    2024
# 31  Zhong nan da xue xue bao. Yi xue ban = Journal...    2024
# 32                            Revista medica de Chile    2024
# 33  Annual International Conference of the IEEE En...    2024
# 34             Journal of research in health sciences    2025
# 35  Nutrition, metabolism, and cardiovascular dise...    2025
# 36                Turkish journal of medical sciences    2025
# 37  Zhong nan da xue xue bao. Yi xue ban = Journal...    2024
# 38  Annual International Conference of the IEEE En...    2024
# 39                Radiologic clinics of North America    2025
# 40                        Hepatology (Baltimore, Md.)    2025
#
#                                              Abstract
# 0   The risk factors involved in obstructive sleep...
# 1   To estimate survival outcomes in a population ...
# 2   <b>Aims/Background</b> The present study aimed...
# 3   Afamin is a vitamin E-binding glycoprotein pri...
# 4   Skeletal muscle (SM) health has significant pr...
# 5   Retinol binding protein 4 (RBP4), as a novel a...
# 6   There are limited data about the clinical bene...
# 7   In addition to hypertension or diabetes, elder...
# 8   Clinical trials have shown the kidney-protecti...
# 9   The definition of CKD is broad, which neglects...
# 10  Chronic kidney disease (CKD) is a significant ...
# 11  Although existing evidence suggests that arter...
# 12  Insulin resistance (IR) is closely associated ...
# 13  There is a relative scarcity of large-scale po...
# 14  We aimed to identify different trajectories of...
# 15  The cardiometabolic index (CMI) is a new metri...
# 16  The cardiometabolic index (CMI) is a new metri...
# 17  The cardiovascular risk models and subclinical...
# 18  To date, many studies have shown a link betwee...
# 19  The prognostic value of changes in arterial st...
# 20  To investigate the impact of visceral adipose ...
# 21  To investigate the causal associations between...
# 22  To study the associations between risk factors...
# 23  Acute myocardial infarction (AMI) is a leading...
# 24  Frequent consumption of sugar-sweetened bevera...
# 25  To examine the association between the age at ...
# 26  Coronary heart disease (CHD) has been recogniz...
# 27  The recent conceptualization of the cardiovasc...
# 28  Risk stratification for cognitive impairment i...
# 29  Diabetes mellitus is the most common cause of ...
# 30  Cardiovascular disease (CVD), particularly isc...
# 31  Osteoporosis is characterized by decreased bon...
# 32  The prevalence of idiopathic intracranial hype...
# 33  Traditional methods for monitoring blood press...
# 34  Hypertension (HTN) elevates blood pressure (BP...
# 35  Difference in metabolic status may cause incon...
# 36  Pregnancy induces significant cardiovascular c...
# 37  Osteoporosis is characterized by decreased bon...
# 38  Persons who have experienced a prior myocardia...
# 39  Pulmonary vascular diseases, particularly when...
# 40  Around 750,000 patients per year will be cured...

# %%
df_results.to_excel('./pubmed_search.xlsx')
